# %% [markdown]
# # Case NPS Preditivo - Limpeza e Tratamentos dos Dados

# %% [markdown]
# ## Pacotes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Leitura de Dados

# %%
#load dos dados
dados = pd.read_csv("https://raw.githubusercontent.com/braga0m/TechChallenge1/refs/heads/main/dados/desafio_nps_fase_1.csv")

# %%
#20 primeiras linhas dos dados
dados.head(10)
# Out:
#    customer_id  customer_age customer_region  customer_tenure_months  \
# 0            1            63        Nordeste                      14
# 1            2            20             Sul                       1
# 2            3            46        Nordeste                     111
# 3            4            52    Centro-Oeste                     117
# 4            5            56           Norte                      50
# 5            6            35         Sudeste                      75
# 6            7            37         Sudeste                      68
# 7            8            60             Sul                      37
# 8            9            40             Sul                      60
# 9           10            51         Sudeste                      70
#
#    order_id  order_value  items_quantity  discount_value  \
# 0     50001       139.73               4           39.35
# 1     50002       458.95               2            9.51
# 2     50003       507.06               5           42.82
# 3     50004       302.19               2           19.58
# 4     50005       253.06               1           29.37
# 5     50006       568.76               6           36.58
# 6     50007        41.29               3           99.62
# 7     50008       428.76               4           29.54
# 8     50009       121.56               3           91.95
# 9     50010       411.01               6           37.47
#
#    payment_installments  delivery_time_days  delivery_delay_days  \
# 0                     4                   2                    2
# 1                    10                   6                    4
# 2                     6                   6                    1
# 3                     9                   5                    2
# 4                    11                  13                    1
# 5                     3                   4                    5
# 6                     6                   8                    3
# 7                    10                  11                    5
# 8                     6                   6                    3
# 9                     3                   9                    2
#
#    freight_value  delivery_attempts  customer_service_contacts  \
# 0          55.53                  3                          0
# 1          28.23                  3                          0
# 2          40.99                  1                          4
# 3          35.24                  3                          1
# 4          39.32                  1                          1
# 5          41.82                  2                          2
# 6          35.83                  3                          3
# 7          44.50                  1                          0
# 8          24.88                  2                          1
# 9          30.59                  1                          0
#
#    resolution_time_days  nps_score  repeat_purchase_30d  complaints_count  \
# 0                     4        6.9                    0                 3
# 1                    10        2.4                    0                 3
# 2                     5        4.8                    0                 7
# 3                    11        5.9                    0                 4
# 4                     0        6.1                    0                 3
# 5                     3        0.9                    0                 5
# 6                     4        1.4                    0                 6
# 7                     2        0.0                    0                 2
# 8                     9        6.2                    0                 3
# 9                     7        2.7                    0                 2
#
#    csat_internal_score
# 0                  6.5
# 1                  0.0
# 2                  1.5
# 3                  0.3
# 4                  7.9
# 5                  1.5
# 6                  0.6
# 7                  4.1
# 8                  0.8
# 9                  4.2

# %%
#informações básica dos dados
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                2500 non-null   int64
#  1   customer_age               2500 non-null   int64
#  2   customer_region            2500 non-null   object
#  3   customer_tenure_months     2500 non-null   int64
#  4   order_id                   2500 non-null   int64
#  5   order_value                2500 non-null   float64
#  6   items_quantity             2500 non-null   int64
#  7   discount_value             2500 non-null   float64
#  8   payment_installments       2500 non-null   int64
#  9   delivery_time_days         2500 non-null   int64
#  10  delivery_delay_days        2500 non-null   int64
#  11  freight_value              2500 non-null   float64
#  12  delivery_attempts          2500 non-null   int64
#  13  customer_service_contacts  2500 non-null   int64
#  14  resolution_time_days       2500 non-null   int64
#  15  nps_score                  2500 non-null   float64
#  16  repeat_purchase_30d        2500 non-null   int64
#  17  complaints_count           2500 non-null   int64
#  18  csat_internal_score        2500 non-null   float64
# dtypes: float64(5), int64(13), object(1)
# memory usage: 371.2+ KB

# %%
#tamanho dos dados
dados.shape
# Out:
# (2500, 19)

# %%
#summary dos dados
dados.describe().round(3)
# Out:
#        customer_id  customer_age  customer_tenure_months   order_id  \
# count     2500.000      2500.000                2500.000   2500.000
# mean      1250.500        43.396                  61.322  51250.500
# std        721.832        14.888                  34.479    721.832
# min          1.000        18.000                   1.000  50001.000
# 25%        625.750        31.000                  31.000  50625.750
# 50%       1250.500        43.000                  62.000  51250.500
# 75%       1875.250        56.000                  91.000  51875.250
# max       2500.000        69.000                 119.000  52500.000
#
#        order_value  items_quantity  discount_value  payment_installments  \
# count     2500.000        2500.000        2500.000              2500.000
# mean       434.260           3.471          29.746                 6.004
# std        289.772           1.687          29.226                 3.160
# min          7.760           1.000           0.020                 1.000
# 25%        220.245           2.000           8.885                 3.000
# 50%        375.515           3.000          20.935                 6.000
# 75%        577.290           5.000          40.832                 9.000
# max       1983.810           6.000         230.330                11.000
#
#        delivery_time_days  delivery_delay_days  freight_value  \
# count            2500.000             2500.000       2500.000
# mean                8.022                2.187         38.217
# std                 3.770                1.454         12.076
# min                 2.000                0.000          2.620
# 25%                 5.000                1.000         29.928
# 50%                 8.000                2.000         38.500
# 75%                11.000                3.000         46.270
# max                14.000                8.000         76.130
#
#        delivery_attempts  customer_service_contacts  resolution_time_days  \
# count           2500.000                   2500.000              2500.000
# mean               2.006                      1.520                 5.486
# std                0.815                      1.232                 3.458
# min                1.000                      0.000                 0.000
# 25%                1.000                      1.000                 2.000
# 50%                2.000                      1.000                 6.000
# 75%                3.000                      2.000                 8.000
# max                3.000                      7.000                11.000
#
#        nps_score  repeat_purchase_30d  complaints_count  csat_internal_score
# count   2500.000             2500.000          2500.000             2500.000
# mean       4.379                0.087             4.150                2.942
# std        2.510                0.282             1.784                2.379
# min        0.000                0.000             0.000                0.000
# 25%        2.600                0.000             3.000                0.700
# 50%        4.400                0.000             4.000                2.800
# 75%        6.100                0.000             5.000                4.800
# max       10.000                1.000            11.000               10.000

# %%
#checagem de duplicadas nos identificadores
a = len(dados["customer_id"].unique())
b = len(dados["order_id"].unique())

#não há duplicadatas nos identificadores
print(a,b)
# Out:
# 2500 2500

# %%
#não há nenhuma linha duplicada
dados.drop_duplicates()
# Out:
#       customer_id  customer_age customer_region  customer_tenure_months  \
# 0               1            63        Nordeste                      14
# 1               2            20             Sul                       1
# 2               3            46        Nordeste                     111
# 3               4            52    Centro-Oeste                     117
# 4               5            56           Norte                      50
# ...           ...           ...             ...                     ...
# 2495         2496            51             Sul                      96
# 2496         2497            37             Sul                      89
# 2497         2498            19         Sudeste                      98
# 2498         2499            41             Sul                      51
# 2499         2500            35        Nordeste                     109
#
#       order_id  order_value  items_quantity  discount_value  \
# 0        50001       139.73               4           39.35
# 1        50002       458.95               2            9.51
# 2        50003       507.06               5           42.82
# 3        50004       302.19               2           19.58
# 4        50005       253.06               1           29.37
# ...        ...          ...             ...             ...
# 2495     52496       615.81               6           11.41
# 2496     52497        73.03               1           36.44
# 2497     52498       522.78               1            4.84
# 2498     52499        55.87               2            2.11
# 2499     52500       420.94               1           16.51
#
#       payment_installments  delivery_time_days  delivery_delay_days  \
# 0                        4                   2                    2
# 1                       10                   6                    4
# 2                        6                   6                    1
# 3                        9                   5                    2
# 4                       11                  13                    1
# ...                    ...                 ...                  ...
# 2495                     2                  14                    3
# 2496                     3                  12                    2
# 2497                     9                   2                    2
# 2498                     2                  14                    5
# 2499                     4                  11                    1
#
#       freight_value  delivery_attempts  customer_service_contacts  \
# 0             55.53                  3                          0
# 1             28.23                  3                          0
# 2             40.99                  1                          4
# 3             35.24                  3                          1
# 4             39.32                  1                          1
# ...             ...                ...                        ...
# 2495          28.96                  2                          1
# 2496          27.42                  2                          2
# 2497          38.94                  1                          1
# 2498          29.10                  3                          3
# 2499          34.16                  3                          1
#
#       resolution_time_days  nps_score  repeat_purchase_30d  complaints_count  \
# 0                        4        6.9                    0                 3
# 1                       10        2.4                    0                 3
# 2                        5        4.8                    0                 7
# 3                       11        5.9                    0                 4
# 4                        0        6.1                    0                 3
# ...                    ...        ...                  ...               ...
# 2495                     2        3.7                    0                 3
# 2496                     7        3.7                    0                 4
# 2497                     1        7.4                    0                 3
# 2498                     0        2.3                    0                 5
# 2499                     0       10.0                    1                 2
#
#       csat_internal_score
# 0                     6.5
# 1                     0.0
# 2                     1.5
# 3                     0.3
# 4                     7.9
# ...                   ...
# 2495                  4.3
# 2496                  2.5
# 2497                  6.2
# 2498                  1.7
# 2499                  7.6
#
# [2500 rows x 19 columns]

# %% [markdown]
# ## Criação e modificando variáveis

# %%
#criando as categorias a partir do nps_score
# aparentemente np.select() é mais eficiente
dados["nps_categoria"] = dados["nps_score"].case_when([
    (dados["nps_score"] >= 9, "Promotores"),
    ((dados["nps_score"] >= 7) & (dados["nps_score"] < 9), "Neutros"),
    ((dados["nps_score"] >= 0) & (dados["nps_score"] < 7), "Detratores")
    ])


dados[["nps_score", "nps_categoria", "csat_internal_score"]].head(20)
# Out:
#     nps_score nps_categoria  csat_internal_score
# 0         6.9    Detratores                  6.5
# 1         2.4    Detratores                  0.0
# 2         4.8    Detratores                  1.5
# 3         5.9    Detratores                  0.3
# 4         6.1    Detratores                  7.9
# 5         0.9    Detratores                  1.5
# 6         1.4    Detratores                  0.6
# 7         0.0    Detratores                  4.1
# 8         6.2    Detratores                  0.8
# 9         2.7    Detratores                  4.2
# 10        5.3    Detratores                  2.7
# 11        7.0       Neutros                  5.8
# 12        3.7    Detratores                  0.4
# 13        2.9    Detratores                  3.5
# 14        2.7    Detratores                  2.4
# 15        6.0    Detratores                  0.0
# 16        1.9    Detratores                  2.7
# 17        4.8    Detratores                  0.0
# 18        3.4    Detratores                  2.0
# 19        2.0    Detratores                  5.0

# %%
#variável categórica se teve reclamação ou não
dados["complaints"] = np.where(dados["complaints_count"] > 0, 1, 0)

dados[["complaints", "complaints_count"]].head(20)
# Out:
#     complaints  complaints_count
# 0            1                 3
# 1            1                 3
# 2            1                 7
# 3            1                 4
# 4            1                 3
# 5            1                 5
# 6            1                 6
# 7            1                 2
# 8            1                 3
# 9            1                 2
# 10           1                 6
# 11           1                 2
# 12           1                 4
# 13           1                 2
# 14           1                 3
# 15           1                 2
# 16           1                 4
# 17           1                 4
# 18           1                 4
# 19           1                 4

# %%
###dias de atraso
dados["delay_categoria"] = dados["delivery_delay_days"].case_when([
    (dados["delivery_delay_days"] == 0, "0"),
    (dados["delivery_delay_days"] == 1, "1"),
    (dados["delivery_delay_days"] == 2, "2"),
    (dados["delivery_delay_days"] == 3, "3"),
    (dados["delivery_delay_days"].isin([4,5,6,7,8]), "4+"),
])

###
dados["delay_categoria"] = pd.Categorical(
    dados["delay_categoria"],
    categories=["0", "1", "2", "3", "4+"],
    ordered=True
)

###
dados[["delivery_delay_days", "delay_categoria"]].head(20)
# Out:
#     delivery_delay_days delay_categoria
# 0                     2               2
# 1                     4              4+
# 2                     1               1
# 3                     2               2
# 4                     1               1
# 5                     5              4+
# 6                     3               3
# 7                     5              4+
# 8                     3               3
# 9                     2               2
# 10                    2               2
# 11                    1               1
# 12                    2               2
# 13                    1               1
# 14                    3               3
# 15                    3               3
# 16                    2               2
# 17                    3               3
# 18                    4              4+
# 19                    2               2

# %%
####
dados["repeat_purchase_30d_labeled"] = dados["repeat_purchase_30d"].case_when([
    (dados["repeat_purchase_30d"] == 0, "Não"),
    (dados["repeat_purchase_30d"] == 1, "Sim"),
])

# %% [markdown]
# ## Renomeando as colunas

# %%
#renomeando as colunas
dados2 = dados.rename(columns = {
"customer_id": "Cliente ID",
"order_id": "Pedido ID",
"customer_age": "Idade do cliente",
"customer_region": "Região do Cliente",
"customer_tenure_months": "Tempo de relacionamento com o cliente",
"order_value": "Valor do pedido",
"items_quantity": "Quantidade de itens",
"discount_value": "Valor do desconto",
"payment_installments": "Número de parcelas",
"delivery_time_days": "Tempo total da entrega",
"delivery_delay_days": "Tempo de atraso da entrega",
"freight_value": "Valor do frete",
"delivery_attempts": "Número de tentativas de entrega",
"customer_service_contacts": "Número atendimentos",
"resolution_time_days": "Tempo de resolucão de problemas",
"complaints_count": "Número de reclamações",
"repeat_purchase_30d": "Recompra em 30 dias",
"complaints": "Reclamação",
"nps_score": "NPS escore",
"csat_internal_score": "CSAT escore interno",
"delay_categoria": "Dias de atraso na entrega",
"repeat_purchase_30d_labeled": "Recompra em 30 dias (ajustado)",
"nps_categoria":" NPS categoria"
})

# %%
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Cliente ID                             2500 non-null   int64
#  1   Idade do cliente                       2500 non-null   int64
#  2   Região do Cliente                      2500 non-null   object
#  3   Tempo de relacionamento com o cliente  2500 non-null   int64
#  4   Pedido ID                              2500 non-null   int64
#  5   Valor do pedido                        2500 non-null   float64
#  6   Quantidade de itens                    2500 non-null   int64
#  7   Valor do desconto                      2500 non-null   float64
#  8   Número de parcelas                     2500 non-null   int64
#  9   Tempo total da entrega                 2500 non-null   int64
#  10  Tempo de atraso da entrega             2500 non-null   int64
#  11  Valor do frete                         2500 non-null   float64
#  12  Número de tentativas de entrega        2500 non-null   int64
#  13  Número atendimentos                    2500 non-null   int64
#  14  Tempo de resolucão de problemas        2500 non-null   int64
#  15  NPS escore                             2500 non-null   float64
#  16  Recompra em 30 dias                    2500 non-null   int64
#  17  Número de reclamações                  2500 non-null   int64
#  18  CSAT escore interno                    2500 non-null   float64
#  19  nps_categoria                          2500 non-null   object
#  20  Reclamação                             2500 non-null   int64
#  21  Dias de atraso na entrega              2500 non-null   category
#  22  Recompra em 30 dias (ajustado)         2500 non-null   object
# dtypes: category(1), float64(5), int64(14), object(3)
# memory usage: 432.5+ KB

# %%
dados2.head(20)
# Out:
#     Cliente ID  Idade do cliente Região do Cliente  \
# 0            1                63          Nordeste
# 1            2                20               Sul
# 2            3                46          Nordeste
# 3            4                52      Centro-Oeste
# 4            5                56             Norte
# 5            6                35           Sudeste
# 6            7                37           Sudeste
# 7            8                60               Sul
# 8            9                40               Sul
# 9           10                51           Sudeste
# 10          11                50      Centro-Oeste
# 11          12                67             Norte
# 12          13                65      Centro-Oeste
# 13          14                27           Sudeste
# 14          15                50           Sudeste
# 15          16                64             Norte
# 16          17                50             Norte
# 17          18                65               Sul
# 18          19                43               Sul
# 19          20                37      Centro-Oeste
#
#     Tempo de relacionamento com o cliente  Pedido ID  Valor do pedido  \
# 0                                      14      50001           139.73
# 1                                       1      50002           458.95
# 2                                     111      50003           507.06
# 3                                     117      50004           302.19
# 4                                      50      50005           253.06
# 5                                      75      50006           568.76
# 6                                      68      50007            41.29
# 7                                      37      50008           428.76
# 8                                      60      50009           121.56
# 9                                      70      50010           411.01
# 10                                     28      50011           616.17
# 11                                     81      50012           509.48
# 12                                     85      50013           588.28
# 13                                     42      50014           165.19
# 14                                    113      50015           220.81
# 15                                    114      50016           732.83
# 16                                     70      50017           391.66
# 17                                     21      50018           483.04
# 18                                     86      50019           383.98
# 19                                     74      50020           288.93
#
#     Quantidade de itens  Valor do desconto  Número de parcelas  \
# 0                     4              39.35                   4
# 1                     2               9.51                  10
# 2                     5              42.82                   6
# 3                     2              19.58                   9
# 4                     1              29.37                  11
# 5                     6              36.58                   3
# 6                     3              99.62                   6
# 7                     4              29.54                  10
# 8                     3              91.95                   6
# 9                     6              37.47                   3
# 10                    2              23.00                   8
# 11                    2              10.42                   1
# 12                    6              12.54                   5
# 13                    5              52.82                   5
# 14                    3              30.73                   6
# 15                    2              13.24                   8
# 16                    4               0.25                  11
# 17                    1              28.08                   1
# 18                    3              33.61                  11
# 19                    2              20.80                   9
#
#     Tempo total da entrega  ...  Número atendimentos  \
# 0                        2  ...                    0
# 1                        6  ...                    0
# 2                        6  ...                    4
# 3                        5  ...                    1
# 4                       13  ...                    1
# 5                        4  ...                    2
# 6                        8  ...                    3
# 7                       11  ...                    0
# 8                        6  ...                    1
# 9                        9  ...                    0
# 10                       4  ...                    0
# 11                      11  ...                    1
# 12                      11  ...                    1
# 13                      10  ...                    0
# 14                       7  ...                    1
# 15                       9  ...                    1
# 16                       3  ...                    1
# 17                      12  ...                    1
# 18                       3  ...                    2
# 19                       9  ...                    1
#
#     Tempo de resolucão de problemas  NPS escore  Recompra em 30 dias  \
# 0                                 4         6.9                    0
# 1                                10         2.4                    0
# 2                                 5         4.8                    0
# 3                                11         5.9                    0
# 4                                 0         6.1                    0
# 5                                 3         0.9                    0
# 6                                 4         1.4                    0
# 7                                 2         0.0                    0
# 8                                 9         6.2                    0
# 9                                 7         2.7                    0
# 10                                7         5.3                    0
# 11                                3         7.0                    0
# 12                                9         3.7                    0
# 13                                8         2.9                    0
# 14                                4         2.7                    0
# 15                                8         6.0                    0
# 16                                6         1.9                    0
# 17                               10         4.8                    0
# 18                                3         3.4                    0
# 19                                3         2.0                    0
#
#     Número de reclamações  CSAT escore interno  nps_categoria  Reclamação  \
# 0                       3                  6.5     Detratores           1
# 1                       3                  0.0     Detratores           1
# 2                       7                  1.5     Detratores           1
# 3                       4                  0.3     Detratores           1
# 4                       3                  7.9     Detratores           1
# 5                       5                  1.5     Detratores           1
# 6                       6                  0.6     Detratores           1
# 7                       2                  4.1     Detratores           1
# 8                       3                  0.8     Detratores           1
# 9                       2                  4.2     Detratores           1
# 10                      6                  2.7     Detratores           1
# 11                      2                  5.8        Neutros           1
# 12                      4                  0.4     Detratores           1
# 13                      2                  3.5     Detratores           1
# 14                      3                  2.4     Detratores           1
# 15                      2                  0.0     Detratores           1
# 16                      4                  2.7     Detratores           1
# 17                      4                  0.0     Detratores           1
# 18                      4                  2.0     Detratores           1
# 19                      4                  5.0     Detratores           1
#
#     Dias de atraso na entrega Recompra em 30 dias (ajustado)
# 0                           2                            Não
# 1                          4+                            Não
# 2                           1                            Não
# 3                           2                            Não
# 4                           1                            Não
# 5                          4+                            Não
# 6                           3                            Não
# 7                          4+                            Não
# 8                           3                            Não
# 9                           2                            Não
# 10                          2                            Não
# 11                          1                            Não
# 12                          2                            Não
# 13                          1                            Não
# 14                          3                            Não
# 15                          3                            Não
# 16                          2                            Não
# 17                          3                            Não
# 18                         4+                            Não
# 19                          2                            Não
#
# [20 rows x 23 columns]

# %% [markdown]
# ## Exportação

# %%
#exportação das bases de dados
dados.to_csv('dados_ecommerce.csv', index=False)
dados2.to_csv('dados_ecommerce_renomeado.csv', index=False)
